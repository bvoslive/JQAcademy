# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Lendo dados

# %%
# import básicos do pandas e numpy
import pandas as pd
import numpy as np

# %%
# arquivos csv
heart = pd.read_csv('heart.csv')
suicide = pd.read_csv('master.csv')
crime_boston = pd.read_csv('crime_boston.csv', encoding='latin', low_memory=False)

# %% [markdown]
# ## Olhando para os Dataframes

# %%
# .head() retorna as 5 primeiras linhas e .tail() as 5 últimas
heart.head()
heart.tail()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# ...

# %% [markdown]
# ## Infos sobre os Dataframes

# %%
print('Infos básicas do df suicide:')
print('----------------------------')
print(suicide.info())
# Out:
# Infos básicas do df suicide:
# ----------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 12 columns):
# country               27820 non-null object
# year                  27820 non-null int64
# sex                   27820 non-null object
# age                   27820 non-null object
# suicides_no           27820 non-null int64
# population            27820 non-null int64
# suicides/100k pop     27820 non-null float64
# country-year          27820 non-null object
# HDI for year          8364 non-null float64
#  gdp_for_year ($)     27820 non-null object
# gdp_per_capita ($)    27820 non-null int64
# generation            27820 non-null object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 2.5+ MB
# None

# %%
# quantidade de linhas e colunas no df com .shape - (linhas, colunas)
print('Linhas e colunas em suicide: ', suicide.shape)
print('Linhas e colunas em heart: ', heart.shape)
print('Linhas e colunas em crime_boston: ', crime_boston.shape)
# Out:
# Linhas e colunas em suicide:  (27820, 12)
# Linhas e colunas em heart:  (303, 14)
# Linhas e colunas em crime_boston:  (327820, 17)

# %%
# nomes das colunas
suicide.columns
heart.columns
crime_boston.columns
# Out:
# Index(['country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicides/100k pop', 'country-year', 'HDI for year',
#        ' gdp_for_year ($) ', 'gdp_per_capita ($)', 'generation'],
#       dtype='object')
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')
# Index(['INCIDENT_NUMBER', 'OFFENSE_CODE', 'OFFENSE_CODE_GROUP',
#        'OFFENSE_DESCRIPTION', 'DISTRICT', 'REPORTING_AREA', 'SHOOTING',
#        'OCCURRED_ON_DATE', 'YEAR', 'MONTH', 'DAY_OF_WEEK', 'HOUR', 'UCR_PART',
#        'STREET', 'Lat', 'Long', 'Location'],
#       dtype='object')

# %% [markdown]
# ## Acessando colunas com colchetes

# %%
# notação de colchetes retorna um series
heart['age']
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
# 5      57
# 6      56
# 7      44
# 8      52
# 9      57
# 10     54
# 11     48
# 12     49
# 13     64
# 14     58
# 15     50
# 16     58
# 17     66
# 18     43
# 19     69
# 20     59
# 21     44
# 22     42
# 23     61
# 24     40
# 25     71
# 26     59
# 27     51
# 28     65
# 29     53
#        ..
# 273    58
# 274    47
# 275    52
# 276    58
# 277    57
# 278    58
# 279    61
# 280    42
# 281    52
# 282    59
# 283    40
# 284    61
# 285    46
# 286    59
# 287    57
# 288    57
# 289    55
# 290    61
# 291    58
# 292    58
# 293    67
# 294    44
# 295    63
# 296    63
# 297    59
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %%
# retornando df com colchetes
heart[['oldpeak']]
# Out:
#      oldpeak
# 0        2.3
# 1        3.5
# 2        1.4
# 3        0.8
# 4        0.6
# 5        0.4
# 6        1.3
# 7        0.0
# 8        0.5
# 9        1.6
# 10       1.2
# 11       0.2
# 12       0.6
# 13       1.8
# 14       1.0
# 15       1.6
# 16       0.0
# 17       2.6
# 18       1.5
# 19       1.8
# 20       0.5
# 21       0.4
# 22       0.0
# 23       1.0
# 24       1.4
# 25       0.4
# 26       1.6
# 27       0.6
# 28       0.8
# 29       1.2
# ..       ...
# 273      0.1
# 274      1.0
# 275      1.0
# 276      2.0
# 277      0.3
# 278      0.0
# 279      3.6
# 280      1.8
# 281      1.0
# 282      2.2
# 283      0.0
# 284      1.9
# 285      1.8
# 286      0.8
# 287      0.0
# 288      3.0
# 289      2.0
# 290      0.0
# 291      4.4
# 292      2.8
# 293      0.8
# 294      2.8
# 295      4.0
# 296      0.0
# 297      1.0
# 298      0.2
# 299      1.2
# 300      3.4
# 301      1.2
# 302      0.0
#
# [303 rows x 1 columns]

# %%
# acessando mais de uma coluna
heart[['age', 'slope', 'restecg']]
# Out:
#      age  slope  restecg
# 0     63      0        0
# 1     37      0        1
# 2     41      2        0
# 3     56      2        1
# 4     57      2        1
# 5     57      1        1
# 6     56      1        0
# 7     44      2        1
# 8     52      2        1
# 9     57      2        1
# 10    54      2        1
# 11    48      2        1
# 12    49      2        1
# 13    64      1        0
# 14    58      2        0
# 15    50      1        1
# 16    58      2        1
# 17    66      0        1
# 18    43      2        1
# 19    69      2        1
# 20    59      1        1
# 21    44      2        1
# 22    42      2        1
# 23    61      1        1
# 24    40      2        1
# 25    71      2        1
# 26    59      2        1
# 27    51      2        1
# 28    65      2        0
# 29    53      0        0
# ..   ...    ...      ...
# 273   58      2        1
# 274   47      1        0
# 275   52      2        1
# 276   58      1        1
# 277   57      2        1
# ...

# %%
# veja a diferença de tipos
type(heart['age'])
type(heart[['oldpeak']])
# Out:
# pandas.core.series.Series
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Acessando colunas e linhas com .loc[] e .iloc[]

# %%
# .loc[ linhas , colunas], os filtros devem ser iguais aos labels do df
heart.loc[ :3 , :] #index 3 para trás e todas as colunas
heart.loc[2:4, ['age', 'sex']] #index 2 ao 4 e as colunas age e sex
heart.loc[30:35, 'fbs'] #index 30 ao 35 e coluna fbs, perceba que retornou uma series
heart.loc[100:104, ['oldpeak', 'thal']] #index 100 ao 104 e colunas oldpeak e thal
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
#    age  sex
# 2   41    0
# 3   56    1
# 4   57    0
# 30    0
# 31    0
# 32    0
# 33    0
# 34    0
# 35    0
# Name: fbs, dtype: int64
#      oldpeak  thal
# 100      0.8     2
# 101      4.2     3
# 102      0.0     2
# 103      0.8     3
# 104      0.0     2

# %%
# .iloc[ linhas , colunas], os filtros devem ser apenas números
heart.iloc[ :3 , :] #index 3 para trás e todas as colunas
heart.iloc[2:4, 0:2] #index 2 ao 4 e as colunas age e sex
heart.iloc[30:35, 5] #index 30 ao 35 e coluna fbs, perceba que retornou uma series
heart.iloc[100:104, [9, 12]] #index 100 ao 104 e colunas oldpeak e thal
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
#    age  sex
# 2   41    0
# 3   56    1
# 30    0
# 31    0
# 32    0
# 33    0
# 34    0
# Name: fbs, dtype: int64
#      oldpeak  thal
# 100      0.8     2
# 101      4.2     3
# 102      0.0     2
# 103      0.8     3

# %% [markdown]
# **Perceba a igualdade nas saídas dos dois comandos**

# %% [markdown]
# ## Renomeando colunas de um DF
#
# **Há várias maneiras de se fazer isso, vamos mostrar algumas**

# %%
# renomando com .rename(), alteração não acontece "inplace", você deve atribuir a mudança ao df novamente
heart = heart.rename(columns={'age' : 'idade', 'sex' : 'sexo'})
heart.head(3)
# Out:
#    idade  sexo  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63     1   3       145   233    1        0      150      0      2.3
# 1     37     1   2       130   250    0        1      187      0      3.5
# 2     41     0   1       130   204    0        0      172      0      1.4
#
#    slope  ca  thal  target
# 0      0   0     1       1
# 1      0   0     2       1
# 2      2   0     2       1

# %%
# renomeando com uma lista, vou usar uma subconjunto do df heart para ficar mais simples
heart = pd.read_csv('heart.csv')
heart_clean = heart[['age', 'sex', 'trestbps', 'thalach', 'target']]

# %%
print('DF antes de renomear as colunas')
print('-------------------------------')
print(heart_clean.head(3))

novos_nomes = ['idade', 'sexo', 'press_sang_descanso', 'max_bat_cardi', 'target_variable']
heart_clean.columns = novos_nomes

print('\n\nDF após renomear as colunas')
print('-------------------------------')
print(heart_clean.head(3))
# Out:
# DF antes de renomear as colunas
# -------------------------------
#    age  sex  trestbps  thalach  target
# 0   63    1       145      150       1
# 1   37    1       130      187       1
# 2   41    0       130      172       1
#
#
# DF após renomear as colunas
# -------------------------------
#    idade  sexo  press_sang_descanso  max_bat_cardi  target_variable
# 0     63     1                  145            150                1
# 1     37     1                  130            187                1
# 2     41     0                  130            172                1

# %% [markdown]
# ## Filtrando linhas com filtros booleanos

# %%
heart = pd.read_csv('heart.csv')
suicide = pd.read_csv('master.csv')
crime_boston = pd.read_csv('crime_boston.csv', encoding='latin', low_memory=False)

# %%
#crie um series booleana com a condição desejada, depois passe como filtro para o df usando colchetes ou .loc[]
filt_1 = crime_boston['OFFENSE_CODE_GROUP'] == 'Disorderly Conduct'

crime_boston[filt_1]
crime_boston.loc[filt_1, :] #todas as linhas que respeitam a condição e todas as colunas
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0           I182080058          2403  Disorderly Conduct
# 172         I182079868          2401  Disorderly Conduct
# 179         I182079857          2405  Disorderly Conduct
# 676         I182079307          2405  Disorderly Conduct
# 774         I182079203          2403  Disorderly Conduct
# 1242        I182078692          2403  Disorderly Conduct
# 1249        I182078685          2405  Disorderly Conduct
# 1279        I182078649          2405  Disorderly Conduct
# 1365        I182078556          2405  Disorderly Conduct
# 1366        I182078556          2403  Disorderly Conduct
# 1539        I182078374          2405  Disorderly Conduct
# 1637        I182078264          2405  Disorderly Conduct
# 1770        I182078119          2401  Disorderly Conduct
# 1782        I182078108          2401  Disorderly Conduct
# 1794        I182078096          2403  Disorderly Conduct
# ...

# %% [markdown]
# **Perceba que as duas saídas são iguais**

# %%
# usando mais de um filtro de uma vez
filt_1 = crime_boston['OFFENSE_CODE_GROUP'] == 'Disorderly Conduct'
filt_2 = crime_boston['DAY_OF_WEEK'] == 'Wednesday'

crime_boston.loc[filt_1 & filt_2, ['OFFENSE_CODE_GROUP', 'DAY_OF_WEEK', 'DISTRICT', 'YEAR']]
# Out:
#         OFFENSE_CODE_GROUP DAY_OF_WEEK DISTRICT  YEAR
# 0       Disorderly Conduct   Wednesday      E18  2018
# 179     Disorderly Conduct   Wednesday       C6  2018
# 1794    Disorderly Conduct   Wednesday       B2  2018
# 4146    Disorderly Conduct   Wednesday      E18  2018
# 4173    Disorderly Conduct   Wednesday       B2  2018
# 5878    Disorderly Conduct   Wednesday       A1  2018
# 6114    Disorderly Conduct   Wednesday      C11  2018
# 6119    Disorderly Conduct   Wednesday      C11  2018
# 8003    Disorderly Conduct   Wednesday       A1  2018
# 9789    Disorderly Conduct   Wednesday       D4  2018
# 9831    Disorderly Conduct   Wednesday       A1  2018
# 11756   Disorderly Conduct   Wednesday      A15  2018
# 11920   Disorderly Conduct   Wednesday       A1  2018
# 11998   Disorderly Conduct   Wednesday       D4  2018
# 12013   Disorderly Conduct   Wednesday       A1  2018
# 13908   Disorderly Conduct   Wednesday       A1  2018
# ...

# %% [markdown]
# **Filtramos linhas que tinham OFFENSE_CODE_GROUP == 'Disorderly Conduct' e DAY_OF_WEEK == 'Wednesday' e depois filtramos apenas as colunas 'OFFENSE_CODE_GROUP', 'DAY_OF_WEEK', 'DISTRICT' e 'YEAR'**

# %% [markdown]
# ## Ordenando por colunas ou valores

# %%
heart = pd.read_csv('heart.csv')
heart.head(3)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1

# %%
# colocando colunas em ordem alfabéticas, ascending=True é o valor default
heart_col_alfa = heart.sort_index(axis=1)
heart_col_alfa.head(3)

# colocando colunas em ordem alfabética "descrescente"
heart_col_nao_alfa = heart.sort_index(axis=1, ascending=False)
heart_col_nao_alfa.head(3)

# colocando index em ordem descrescente
heart_ind_decre = heart.sort_index(axis=0, ascending=False)
heart_ind_decre.head(3)
# Out:
#    age  ca  chol  cp  exang  fbs  oldpeak  restecg  sex  slope  target  thal  \
# 0   63   0   233   3      0    1      2.3        0    1      0       1     1
# 1   37   0   250   2      0    0      3.5        1    1      0       1     2
# 2   41   0   204   1      0    0      1.4        0    0      2       1     2
#
#    thalach  trestbps
# 0      150       145
# 1      187       130
# 2      172       130
#    trestbps  thalach  thal  target  slope  sex  restecg  oldpeak  fbs  exang  \
# 0       145      150     1       1      0    1        0      2.3    1      0
# 1       130      187     2       1      0    1        1      3.5    0      0
# 2       130      172     2       1      2    0        0      1.4    0      0
#
#    cp  chol  ca  age
# 0   3   233   0   63
# 1   2   250   0   37
# 2   1   204   0   41
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 302   57    0   1       130   236    0        0      174      0      0.0
# ...

# %%
# ordenando por valores
heart.sort_values(by='age')
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 72    29    1   1       130   204    0        0      202      0      0.0
# 58    34    1   3       118   182    0        0      174      0      0.0
# 125   34    0   1       118   210    0        1      192      0      0.7
# 239   35    1   0       126   282    0        0      156      1      0.0
# 65    35    0   0       138   183    0        1      182      0      1.4
# 227   35    1   0       120   198    0        1      130      1      1.6
# 157   35    1   1       122   192    0        1      174      0      0.0
# 1     37    1   2       130   250    0        1      187      0      3.5
# 115   37    0   2       120   215    0        1      170      0      0.0
# 164   38    1   2       138   175    0        1      173      0      0.0
# 163   38    1   2       138   175    0        1      173      0      0.0
# 259   38    1   3       120   231    0        1      182      1      3.8
# ...

# %% [markdown]
# ## Usando o groupby()

# %%
crime_boston = pd.read_csv('crime_boston.csv', encoding='latin', low_memory=False)
crime_boston.head(3)
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0      I182080058          2403  Disorderly Conduct
# 1      I182080053          3201       Property Lost
# 2      I182080052          2647               Other
#
#          OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# 0       DISTURBING THE PEACE      E18            495      NaN
# 1            PROPERTY - LOST      D14            795      NaN
# 2  THREATS TO DO BODILY HARM       B2            329      NaN
#
#       OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR    UCR_PART  \
# 0  2018-10-03 20:13:00  2018     10   Wednesday    20    Part Two
# 1  2018-08-30 20:00:00  2018      8    Thursday    20  Part Three
# 2  2018-10-03 19:20:00  2018     10   Wednesday    19    Part Two
#
#          STREET        Lat       Long                     Location
# 0  ARLINGTON ST  42.262608 -71.121186  (42.26260773, -71.12118637)
# 1    ALLSTON ST  42.352111 -71.135311  (42.35211146, -71.13531147)
# ...

# %%
# normalize=True mostra a frequência relativa 
series_perc = crime_boston.groupby(by=['OFFENSE_CODE_GROUP']).DAY_OF_WEEK.value_counts(normalize=True)
series_perc
# Out:
# OFFENSE_CODE_GROUP                DAY_OF_WEEK
# Aggravated Assault                Saturday       0.166189
#                                   Sunday         0.159467
#                                   Friday         0.142786
#                                   Thursday       0.139051
#                                   Wednesday      0.131458
#                                   Tuesday        0.130835
#                                   Monday         0.130213
# Aircraft                          Saturday       0.243243
#                                   Tuesday        0.189189
#                                   Wednesday      0.189189
#                                   Monday         0.108108
#                                   Thursday       0.108108
#                                   Friday         0.081081
#                                   Sunday         0.081081
# Arson                             Thursday       0.178947
# ...

# %%
series_perc.loc[ ['Aggravated Assault', 'Aircraft'] , ['Saturday', 'Sunday']]
# Out:
# OFFENSE_CODE_GROUP  DAY_OF_WEEK
# Aggravated Assault  Saturday       0.166189
#                     Sunday         0.159467
# Aircraft            Saturday       0.243243
#                     Sunday         0.081081
# Name: DAY_OF_WEEK, dtype: float64

# %% [markdown]
# **.value_counts() funciona muito bem com dados categóricos, vamos ver algumas operaçoes que podemos usar com .groupby()**

# %%
heart = pd.read_csv('heart.csv')
heart.head(3)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1

# %%
heart.groupby(by=['sex', 'target']).agg({'age' : np.mean, 'oldpeak' : np.mean})
# Out:
#                   age   oldpeak
# sex target
# 0   0       59.041667  1.841667
#     1       54.555556  0.554167
# 1   0       56.087719  1.531579
#     1       50.903226  0.605376

# %%
heart.groupby(by=['sex', 'target']).mean()
# Out:
#                   age        cp    trestbps        chol       fbs   restecg  \
# sex target
# 0   0       59.041667  0.166667  146.125000  274.958333  0.250000  0.541667
#     1       54.555556  1.333333  128.736111  256.750000  0.083333  0.583333
# 1   0       56.087719  0.543860  131.929825  246.061404  0.140351  0.429825
#     1       50.903226  1.408602  129.741935  230.989247  0.182796  0.602151
#
#                thalach     exang   oldpeak     slope        ca      thal
# sex target
# 0   0       142.416667  0.583333  1.841667  0.958333  1.291667  2.500000
#     1       154.027778  0.111111  0.554167  1.583333  0.305556  2.000000
# 1   0       138.403509  0.543860  1.531579  1.210526  1.140351  2.552632
#     1       161.903226  0.161290  0.605376  1.602151  0.408602  2.215054

# %% [markdown]
# ## Visualizações rápidas

# %%
#import básico 
import matplotlib.pyplot as plt
# %matplotlib inline

crime_boston = pd.read_csv('crime_boston.csv', encoding='latin', low_memory=False)
heart = pd.read_csv('heart.csv')

# %% [markdown]
# **Usando Series**

# %%
heart['target'].value_counts(normalize=True).plot.bar(title='Freq Relativa do Target', legend=True)

# %%
crime_boston['OFFENSE_CODE_GROUP'].value_counts(normalize=True).plot.barh(title='Freq Relativa do OFFENSE_CODE_GROUP', legend=True, figsize=(8, 16))

# %%
heart[['age', 'oldpeak']].plot.box(title='Box Plot', figsize=(10, 5), subplots=True)
# Out:
# age           AxesSubplot(0.125,0.125;0.352273x0.755)
# oldpeak    AxesSubplot(0.547727,0.125;0.352273x0.755)
# dtype: object

# %%
heart[heart['sex'] == 0]['age'].plot.hist(title='Histograma | Age com sex==0', figsize=(10, 5), legend=True)

# %%
heart['cp'].value_counts().plot.pie(title='Pie Chart | CP Feature', legend=True, figsize=(13, 6))
